# %% [markdown]
# ## Feature engineering

# %%
import utils
import scipy

# %%
import torch 
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F

# %%
# tensorboard 장착
from tensorboardX import SummaryWriter

# %%
writer = SummaryWriter()

# %%
# audio configuration for 푸리에 트랜스폼
audio_conf = {}
audio_conf["sample_rate"] = 16000 # dataset의 sample rate는 16000
audio_conf["window_size"] = 0.02
audio_conf["window_stride"] = 0.01
audio_conf["window"] = scipy.signal.hamming

# %%
# train 파라미터로 7:3 변환
dset_train = utils.SpectogramDataset(audio_conf,'./data/train/audio/',20,train=True)
train_loader = utils.AudioDataLoader(dset_train,20,4) # dataset, batch size, number of workers
dset_test = utils.SpectogramDataset(audio_conf,'./data/train/audio/',20,train=False)
test_loader = utils.AudioDataLoader(dset_test,20,4) # dataset, batch size, number of workers

# %%
len(dset_train)
# Out:
# 44080

# %%
# index로 변환하기 위한 함수
files = {'yes':0,'no':1,'up':2,'down':3,'left':4,'right':5,'on':6,'off':7,'stop':8,'go':9, 'bed':10,'bird':11,'cat':12,'dog':13,'eight':14,
'five':15,'four':16,'happy':17,'house':18,'marvin':19,'nine':20,'one':21,'seven':22,'shella':23,'six':24,'three':25,'tree':26,'two':27,'wow':28,'zero':29,
}

# %%
# batch_first: If True, then the input and output tensors are provided as (batch, seq, feature)

# %%
class DNN(nn.Module):
    def __init__(self,input_size, output_size, batch_size):
        super(DNN,self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.batch_size = batch_size
        self.fc1 = nn.Linear(self.input_size,8192)
        self.b1 = nn.BatchNorm1d(8192)
        self.fc2 = nn.Linear(8192,2048)
        self.b2 = nn.BatchNorm1d(2048)
        self.fc3 = nn.Linear(2048,512)
        self.b3 = nn.BatchNorm1d(512)
        self.fc4 = nn.Linear(512,128)
        self.b4 = nn.BatchNorm1d(128)
        self.fc5 = nn.Linear(128,30)
        self.b5 = nn.BatchNorm1d(30)
    def forward(self, x):
        out = F.relu(self.b1(self.fc1(x)))
        out = F.relu(self.b2(self.fc2(out)))
        out = F.relu(self.b3(self.fc3(out)))
        out = F.relu(self.b4(self.fc4(out)))
        out = self.fc5(out)
        out = F.softmax(out)
        return out

# %%
class LSTM(nn.Module):
    def __init__(self,input_size,hidden_size, num_hidden_layer,batch_size):
        super(LSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_hidden_layer = num_hidden_layer
        self.batch_size = batch_size
        self.lstm = nn.LSTM(input_size,hidden_size,num_hidden_layer,bidirectional = True,batch_first = True) # input_size, hidden_size, num_layers
        self.fc1 = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.fc2 = nn.Linear(self.hidden_size,30)
        self.softmax = nn.Softmax()
    def forward(self, x):
        h0 = Variable(torch.zeros(self.num_hidden_layer * 2,self.batch_size,self.hidden_size)).cuda()
        c0 = Variable(torch.zeros(self.num_hidden_layer * 2,self.batch_size,self.hidden_size)).cuda()
        x = x.transpose(1,2)
        out, _ = self.lstm(x, (h0,c0))
        out = out[:,-1,:]
        out = F.relu(self.fc1(out))
        out = self.fc2(out)
        out = self.softmax(out)
        return out

# %%
class SequenceWise(nn.Module):
    """
    Collapses input of dim T*N*H to (T*N)*H, and applies to a module.
    Allows handling of variable sequence lengths and minibatch sizes.
    :param module: Module to apply input to.
    """
    """
    총 두 번 사용된다. CNN의 output이 RNN으로 들어갈 때. RNN의 output이 FC로 들어갈 때. 
    그 필요성은 위의 딥 스피치 모델 그림에서 데이터가 transpose됨을 보면 알 수 있다.
    """
    def __init__(self, module):
        super(SequenceWise, self).__init__()
        self.module = module

    def forward(self, x):
        t, n = x.size(0), x.size(1)
        x = x.view(t * n, -1)
        x = self.module(x)
        x = x.view(t, n, -1)
        return x

"""
class InferenceBatchSoftmax(nn.Module):
#    이건 굉장히 typical 한 minibatch softmax.    각 data의 softmax를 torch.stack을 해야한다는 부분이 했심.    QQQQQQQQQQQ 왜 if not self.training인가. 
    def forward(self, input_):
        if not self.training:
            batch_size = input_.size()[0]
            return torch.stack([F.log_softmax(input_[i]) for i in range(batch_size)], 0)
        else:
            return input_
"""        

class BatchRNN(nn.Module):
    """
    batchnormalization + RNN 구현.
    굳이 이런식으로 붙이는 이유는 sequencewise 때문에. 
    input : 
        input_size - T * N * H 에서 H 의 값. 여기서 T 는 time, N 은 mini batch 갯수, H는 P * C(convolution layers)
        hidden_size - output의 값. 
                      여기서 output은 input과 같지 않냐! 고 생각하는데, 단순히 hi = W1 * xi + W2 * xi 라고 했을 때 matrix의 행의 크기. 
                      즉, T * N * H에서 H가 얼마나 압축될 것이냐의 의미.
    """
    def __init__(self, input_size, hidden_size, rnn_type=nn.LSTM, bidirectional=True, batch_norm=True):
        super(BatchRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.bidirectional = bidirectional
        self.batch_norm = SequenceWise(nn.BatchNorm1d(input_size)) if batch_norm else None
        self.rnn = rnn_type(input_size=input_size, hidden_size=hidden_size,
                            bidirectional=bidirectional, bias=False)
        self.num_directions = 2 if bidirectional else 1 # why do I need this?

    def forward(self, x):
        if self.batch_norm is not None:
            x = self.batch_norm(x)
        h0 = Variable(torch.zeros(1 * 2, 20, self.hidden_size)).cuda()# batch size = 20
        c0 = Variable(torch.zeros(1 * 2, 20, self.hidden_size)).cuda()
        x, _ = self.rnn(x,(h0,c0))
        if self.bidirectional:
            x = x.view(x.size(0), x.size(1), 2, -1).sum(2).view(x.size(0), x.size(1), -1)  # (TxNxH*2) -> (TxNxH) by sum
            return x

# %%
import math
"""
deep speech model. 
Input : 
    없어도 된다!
"""
class DeepSpeech(nn.Module):
    def __init__(self, rnn_type=nn.LSTM, num_classes=30 , rnn_hidden_size=768, audio_conf=None,
                 bidirectional=True):
        super(DeepSpeech, self).__init__()

        # model metadata needed for serialization/deserialization
        if audio_conf is None:
            audio_conf = {}
        self._hidden_size = rnn_hidden_size
#        self._hidden_layers = nb_layers
        self._rnn_type = rnn_type
        self._audio_conf = audio_conf or {}

        sample_rate = self._audio_conf.get("sample_rate", 16000)
        window_size = self._audio_conf.get("window_size", 0.02)

        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=(41, 11), stride=(2, 2)),
            nn.BatchNorm2d(32),
            nn.Hardtanh(0, 20, inplace=True),
            nn.Conv2d(32, 32, kernel_size=(21, 11), stride=(2, 1)),
            nn.BatchNorm2d(32),
            nn.Hardtanh(0, 20, inplace=True)
        )
        # Based on above convolutions and spectrogram size using conv formula (W - F + 2P)/ S+1
        rnn_input_size = int(math.floor((sample_rate * window_size) / 2) + 1)
        rnn_input_size = int(math.floor(rnn_input_size - 41) / 2 + 1)
        rnn_input_size = int(math.floor(rnn_input_size - 21) / 2 + 1)
        rnn_input_size *= 32

        rnns = []
        self.rnn = BatchRNN(input_size=rnn_input_size, hidden_size=rnn_hidden_size, rnn_type=rnn_type,
                       bidirectional=bidirectional, batch_norm=True)

        fully_connected = nn.Sequential(
            nn.BatchNorm1d(rnn_hidden_size),
            nn.Linear(rnn_hidden_size, num_classes, bias=False)
        )
        self.fc = nn.Sequential(
            SequenceWise(fully_connected),
        )

    def forward(self, x):
        x = self.conv(x)

        sizes = x.size()
        x = x.view(sizes[0], sizes[1] * sizes[2], sizes[3])  # Collapse feature dimension
        x = x.transpose(1, 2).transpose(0, 1).contiguous()  # TxNxH
        x = self.rnn(x)

        x = self.fc(x)
        x = x.transpose(0, 1)
        x = F.log_softmax(x[:,-1,:])
        return x

# %%
def toidx(key):
    """
    file index를 onehot으로 바꿔줘야 한다.
    input - str. key
    output - list. onehot
    """
    # index로 변환하기 위한 함수
    files = {'yes':0,'no':1,'up':2,'down':3,'left':4,'right':5,'on':6,'off':7,'stop':8,'go':9, 'bed':10,'bird':11,'cat':12,'dog':13,'eight':14,
    'five':15,'four':16,'happy':17,'house':18,'marvin':19,'nine':20,'one':21,'seven':22,'shella':23,'six':24,'three':25,'tree':26,'two':27,'wow':28,'zero':29,
    }
    out = files[key]
    return out

# %%
def tolistidx(lis):
    out = []
    for idx in lis:
        out.append(toidx(idx))
    return out

# %%
model = DNN(161*101,30,20).cuda()

# %%
model = LSTM(161,128,5,20).cuda()

# %%
model = DeepSpeech().cuda()

# %%
criterion = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr = 0.001)

# %%
# training step DNN
epoch = 5
for i in range(epoch):
    print('epoch :', i)
    for j, (images, labels) in enumerate(train_loader):
        images = Variable(images.squeeze().unsqueeze(0).cuda()).view(20,-1)
        labels = Variable(torch.LongTensor(tolistidx(labels)).cuda())
        
        opt.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        opt.step()
        if(j % 100 == 0):
            print(loss)
# Out:
# epoch : 5
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-fb3156350e1f> in <module>()
#       8
#       9         opt.zero_grad()
# ---> 10         outputs = model(images)
#      11         loss = criterion(outputs, labels)
#      12         loss.backward()
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# <ipython-input-20-a728e195d4de> in forward(self, x)
#      13         h0 = Variable(torch.zeros(self.num_hidden_layer * 2,self.batch_size,self.hidden_size)).cuda()
#      14         c0 = Variable(torch.zeros(self.num_hidden_layer * 2,self.batch_size,self.hidden_size)).cuda()
# ---> 15         x = x.transpose(1,2)
#      16         out, _ = self.lstm(x, (h0,c0))
#      17         out = out[:,-1,:]
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/autograd/variable.py in transpose(self, dim1, dim2)
#     731
#     732     def transpose(self, dim1, dim2):
# --> 733         return Transpose.apply(self, dim1, dim2)
#     734
#     735     def select(self, dim, _index):
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, dim1, dim2)
#      78     @staticmethod
#      79     def forward(ctx, i, dim1, dim2):
# ---> 80         result = i.transpose(dim1, dim2)
#      81         ctx.dims = (dim1, dim2)
#      82         ctx.mark_shared_storage((i, result))
#
# RuntimeError: dimension out of range (expected to be in range of [-2, 1], but got 2)

# %%
# training step LSTM
epoch = 5
for i in range(epoch):
    print('epoch :', i)
    for j, (images, labels) in enumerate(train_loader):
        images = Variable(images.squeeze().cuda())
        labels = Variable(torch.LongTensor(tolistidx(labels)).cuda())
        
        opt.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        opt.step()
        if(j % 100 == 0):
            print(loss)
# Out:
# epoch : 0
# Variable containing:
#  3.4014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4016
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4019
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4032
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3973
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3975
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4006
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3990
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4059
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3965
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4006
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3930
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4042
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4079
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3930
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4040
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3970
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4048
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4020
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 1
# Variable containing:
#  3.3911
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3970
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4034
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4012
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3900
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3960
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3965
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3899
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4062
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3972
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4056
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3939
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3940
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3956
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3993
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4011
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3995
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.3916
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4060
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.4043
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 2
# Variable containing:
#  3.3970
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-fd0a5cc915a0> in <module>()
#      10         outputs = model(images)
#      11         loss = criterion(outputs, labels)
# ---> 12         loss.backward()
#      13         opt.step()
#      14         if(j % 100 == 0):
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     154                 Variable.
#     155         """
# --> 156         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     157
#     158     def register_hook(self, hook):
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      96
#      97     Variable._execution_engine.run_backward(
# ---> 98         variables, grad_variables, retain_graph)
#      99
#     100
#
# KeyboardInterrupt:

# %%
# train 파라미터로 7:3 변환
dset_train = utils.SpectogramDataset(audio_conf,'./data/train/audio/',20,train=True)
train_loader = utils.AudioDataLoader(dset_train,20,4) # dataset, batch size, number of workers
dset_test = utils.SpectogramDataset(audio_conf,'./data/train/audio/',20,train=False)
test_loader = utils.AudioDataLoader(dset_test,20,4) # dataset, batch size, number of workers

# %%
# training step deepspeech
epoch = 50
for i in range(epoch):
    print('epoch :', i)
    for j, (images, labels) in enumerate(train_loader):
        images = Variable(images.squeeze().cuda()).unsqueeze(1)
        labels = Variable(torch.LongTensor(tolistidx(labels)).cuda())
    
        opt.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        opt.step()
        writer.add_scalar('./logs/loss_lstm',loss.data.cpu()[0],(epoch)*len(train_loader) + j)
        if(j % 100 == 0):
            print(loss)
            torch.save(model,'./deepspeech_LSTM_3.pth')
# Out:
# epoch : 0
# Variable containing:
#  3.7181
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /home/voithru/anaconda3/envs/torch/lib/python3.6/site-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type DeepSpeech. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/voithru/anaconda3/envs/torch/lib/python3.6/site-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type BatchRNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/voithru/anaconda3/envs/torch/lib/python3.6/site-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type SequenceWise. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Variable containing:
#  2.7105
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  2.6737
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.7832
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.7801
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.5782
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.3476
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4715
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4556
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7913
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.2889
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6633
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2955
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5256
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6041
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1845
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8567
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6561
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6986
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.2420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 1
# Variable containing:
#  0.6786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4148
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2222
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1300
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3679
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.0101
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6314
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5276
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1531
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5142
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3921
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1933
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5350
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.5475
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2065
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4829
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3097
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3216
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4004
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.6711
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 2
# Variable containing:
#  0.5668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.5628
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1080
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.6868
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4244
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.9603
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2915
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.8562
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2451
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5068
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2588
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2209
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.1929
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4114
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8794
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2769
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1720
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.2844
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5238
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 3
# Variable containing:
#  0.2386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1304
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.4126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1711
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2583
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.6348
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1101
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.2730
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1945
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2068
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2164
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   7.4808
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3813
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1919
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.9649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1644
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.0285
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.4589
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2273
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.7330
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1433
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.4162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 4
# Variable containing:
# 1.00000e-03 *
#   4.8674
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.9617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.5045
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.0290
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1375
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2296
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.1825
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2174
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.5221
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1650
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.6502
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3333
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   3.2948
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.3313
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2053
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# Variable containing:
# 1.00000e-02 *
#   6.7568
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.4991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.8498
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2220
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1002
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.0089
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.4952
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1208
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 5
# Variable containing:
# 1.00000e-02 *
#   6.1318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.8631
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.4623
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.7435
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   5.2138
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3115
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.9202
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.7047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   9.6051
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3749
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2055
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.7558
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1395
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.8874
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.7898
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.2289
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1978
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.4122
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.9643
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.8387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.5453
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2350
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2300
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 6
# Variable containing:
# 1.00000e-03 *
#   1.7034
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2868
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1059
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   6.7934
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.7613
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1625
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-04 *
#   3.8833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.6133
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   9.7592
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3349
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2226
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-04 *
#   3.8659
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.4792
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1191
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1488
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1903
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.6262
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.7108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.7947
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3018
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.8444
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1644
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 7
# Variable containing:
# 1.00000e-02 *
#   1.1332
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.0632
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.9595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1858
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   4.8500
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.4181
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.0356
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3640
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.9952
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1529
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1603
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   6.4081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.0989
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.1463
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1993
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.5182
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.4603
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.8519
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.3790
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.1358
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.1363
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3178
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.0545
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 8
# Variable containing:
# 1.00000e-03 *
#   1.9634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.1532
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.1297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   3.5368
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.2958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.5986
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.7660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.3496
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3114
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1408
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1454
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.6846
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.5965
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.5622
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.5236
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1705
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.2990
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   8.3727
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6400
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2004
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.5062
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# Variable containing:
# 1.00000e-03 *
#   2.2476
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 9
# Variable containing:
#  0.3634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2148
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.7543
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.9978
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.0185
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1055
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   4.5841
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2894
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   8.1137
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.2305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.1148
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.3489
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.3355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   9.5863
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.6634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1652
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.5638
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2596
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   8.7490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1133
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1620
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.0096
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 10
# Variable containing:
# 1.00000e-04 *
#   2.9583
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.4841
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.9558
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.8720
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.5727
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1302
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.3217
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.6384
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.9728
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.0845
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.9937
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.2612
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3405
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.2282
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   3.5542
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   7.4750
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.1365
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.0737
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1051
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.6833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.8028
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 11
# Variable containing:
# 1.00000e-02 *
#   5.7916
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.3102
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2854
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.6414
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.9547
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.6733
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3200
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3218
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1703
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2594
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.7253
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   9.3485
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3373
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1688
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2411
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1715
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.8134
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.1569
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   4.7295
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-04 *
#   3.3088
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.8216
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2945
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3321
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 12
# Variable containing:
# 1.00000e-02 *
#   1.1726
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3002
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.8174
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   5.2690
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.0088
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-04 *
#   6.5833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1619
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.6522
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.6901
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   8.0858
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   3.4343
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   3.5972
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-04 *
#   3.2830
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.4598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.3272
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   5.4726
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.0999
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.2637
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-04 *
#   7.8846
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1721
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.4274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3188
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   2.7492
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 13
# Variable containing:
# 1.00000e-03 *
#   1.0018
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.2191
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   4.9897
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.2107
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# Variable containing:
#  0.1818
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.7271
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.1544
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.6743
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.1622
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.3479
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1153
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1645
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.6243
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1496
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   4.7091
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   6.4319
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   2.4132
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   6.3826
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-03 *
#   1.0205
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.6334
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   3.3550
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch : 14
# Variable containing:
# 1.00000e-02 *
#   4.6468
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   1.8685
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2999
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
# Test the Model DNN
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images.squeeze().unsqueeze(0).cuda()).view(20,-1)
    labels = torch.LongTensor(tolistidx(labels)).cuda()
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()
print(correct/total)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-46-59767a570500> in <module>()
#       5     images = Variable(images.squeeze().unsqueeze(0).cuda()).view(20,-1)
#       6     labels = torch.LongTensor(tolistidx(labels)).cuda()
# ----> 7     outputs = model(images)
#       8     _, predicted = torch.max(outputs.data, 1)
#       9     total += labels.size(0)
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# <ipython-input-20-a728e195d4de> in forward(self, x)
#      13         h0 = Variable(torch.zeros(self.num_hidden_layer * 2,self.batch_size,self.hidden_size)).cuda()
#      14         c0 = Variable(torch.zeros(self.num_hidden_layer * 2,self.batch_size,self.hidden_size)).cuda()
# ---> 15         x = x.transpose(1,2)
#      16         out, _ = self.lstm(x, (h0,c0))
#      17         out = out[:,-1,:]
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/autograd/variable.py in transpose(self, dim1, dim2)
#     731
#     732     def transpose(self, dim1, dim2):
# --> 733         return Transpose.apply(self, dim1, dim2)
#     734
#     735     def select(self, dim, _index):
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, dim1, dim2)
#      78     @staticmethod
#      79     def forward(ctx, i, dim1, dim2):
# ---> 80         result = i.transpose(dim1, dim2)
#      81         ctx.dims = (dim1, dim2)
#      82         ctx.mark_shared_storage((i, result))
#
# RuntimeError: dimension out of range (expected to be in range of [-2, 1], but got 2)

# %%
# Test the Model LSTM
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images.squeeze().cuda())
    labels = torch.LongTensor(tolistidx(labels)).cuda()
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()
print(correct/total)
# Out:
# 0.18731501057082453

# %%
# Test the Model deep speech
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images.squeeze().cuda()).unsqueeze(1)
    labels = torch.LongTensor(tolistidx(labels)).cuda()
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()
print(correct/total)
# Out:
# 0.6967105263157894
